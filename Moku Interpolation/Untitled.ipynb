# %%
import pickle
from matplotlib import pyplot as plt
import numpy as np

# %%
op_to_ao = pickle.load( open( "ao_interpolation.pck", "rb" ) )

# %%
op_pow = np.linspace(0,1,1001)

# %%
plt.plot(op_to_ao(op_pow),op_pow)
plt.show()
